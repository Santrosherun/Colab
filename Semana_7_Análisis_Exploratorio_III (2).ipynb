# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Carga de archivo**

# %%
df = pd.read_csv('https://www.datos.gov.co/api/views/ynam-yc42/rows.csv?accessType=DOWNLOAD')
df
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (76,78) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#        ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO  \
# 0                      TI          COLOMBIA           M
# 1                      TI          COLOMBIA           M
# 2                      TI          COLOMBIA           M
# 3                      TI          COLOMBIA           M
# 4                      TI          COLOMBIA           M
# ...                   ...               ...         ...
# 546207                 CC          COLOMBIA           M
# 546208                 TI          COLOMBIA           M
# 546209                 TI          COLOMBIA           M
# 546210                 TI          COLOMBIA           M
# 546211                 TI          COLOMBIA           M
#
# ...

# %%
df.head(2)
# Out:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO    ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           M  02/18/2002 12:00:00 AM
# 1                 TI          COLOMBIA           M  06/28/2003 12:00:00 AM
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_TIENEETNIA ESTU_PAIS_RESIDE  \
# 0    20194  SB11201940031558      ESTUDIANTE              No         COLOMBIA
# 1    20194  SB11201940303339      ESTUDIANTE              No         COLOMBIA
#
#   ESTU_ETNIA  ... PUNT_INGLES PERCENTIL_INGLES DESEMP_INGLES PUNT_GLOBAL  \
# 0          -  ...        54.0               67            A1         208
# 1          -  ...        63.0               88            A2         299
#
#   PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  \
# 0               25     50.9421557404314                 2.0
# 1               83      59.767864431576                 3.0
#
#   ESTU_NSE_ESTABLECIMIENTO ESTU_ESTADOINVESTIGACION ESTU_GENERACION-E
# ...

# %%
df1 = df[['ESTU_TIPODOCUMENTO', 'ESTU_GENERO', 'ESTU_DEPTO_RESIDE', 'ESTU_MCPIO_RESIDE', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES', 'PUNT_INGLES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL']]
df1
# Out:
#        ESTU_TIPODOCUMENTO ESTU_GENERO ESTU_DEPTO_RESIDE    ESTU_MCPIO_RESIDE  \
# 0                      TI           M         MAGDALENA            SANTA ANA
# 1                      TI           M            BOGOTÁ          BOGOTÁ D.C.
# 2                      TI           M           BOLIVAR  CARTAGENA DE INDIAS
# 3                      TI           M            BOGOTÁ          BOGOTÁ D.C.
# 4                      TI           M            BOGOTÁ          BOGOTÁ D.C.
# ...                   ...         ...               ...                  ...
# 546207                 CC           M         ANTIOQUIA            MARINILLA
# 546208                 TI           M            BOGOTÁ          BOGOTÁ D.C.
# 546209                 TI           M            ARAUCA               ARAUCA
# 546210                 TI           M         SANTANDER           VILLANUEVA
# 546211                 TI           M            BOGOTÁ          BOGOTÁ D.C.
#
# ...

# %% [markdown]
# # **Histogramas**

# %%
text_dict = {'size':16,'color':'blue'};
plt.figure(figsize=(8,6));
plt.hist(df1['PUNT_MATEMATICAS'],color='red');
plt.xlabel('Puntaje Matemáticas',fontdict=text_dict);

# %%
text_dict = {'size':16,'color':'blue'};
plt.figure(figsize=(8,6));
plt.hist(df1['PUNT_LECTURA_CRITICA']);
plt.xlabel('Lectura Crítica',fontdict=text_dict);

# %%
sns.set_style('whitegrid');

text_dict = {'size':16,'color':'blue'};
text_legend = {'size':16}
plt.figure(figsize=(8,6));
plt.hist(df1['PUNT_MATEMATICAS'],color='red',alpha=0.4,label='Matemáticas');
plt.hist(df1['PUNT_LECTURA_CRITICA'],color='blue',alpha=0.4,label='Lect Crítica');
#plt.hist(df1['PUNT_INGLES'],color='skyblue',alpha=0.4,label='Inglés');
plt.xlabel('Puntajes',fontdict=text_dict);
plt.legend(loc='best',prop=text_legend);

# %%
plt.figure(figsize=(8,6));
sns.scatterplot(data=df1,x='PUNT_MATEMATICAS',y='PUNT_INGLES',hue='ESTU_GENERO');

# %%
plt.figure(figsize=(8,6));
sns.scatterplot(data=df1,x='PUNT_MATEMATICAS',y='PUNT_C_NATURALES',hue='ESTU_GENERO');

# %%
sns.jointplot(data=df1, x='PUNT_MATEMATICAS',y='PUNT_C_NATURALES',color='g');

# %%
sns.jointplot(data=df1, x='PUNT_MATEMATICAS',y='PUNT_C_NATURALES',color='g',kind='hex');
plt.colorbar()

# %% [markdown]
# **SUBCONJUNTOS**

# %%
df_baq = df1[df1['ESTU_MCPIO_RESIDE']=='BARRANQUILLA'];
df_baq
# Out:
#        ESTU_TIPODOCUMENTO ESTU_GENERO ESTU_DEPTO_RESIDE ESTU_MCPIO_RESIDE  \
# 19                     TI           M         ATLANTICO      BARRANQUILLA
# 23                     TI           M         ATLANTICO      BARRANQUILLA
# 35                     CC           M         ATLANTICO      BARRANQUILLA
# 43                     TI           M         ATLANTICO      BARRANQUILLA
# 51                     TI           M         ATLANTICO      BARRANQUILLA
# ...                   ...         ...               ...               ...
# 545936                NES           F         ATLANTICO      BARRANQUILLA
# 545970                 TI           F         ATLANTICO      BARRANQUILLA
# 546125                 TI           F         ATLANTICO      BARRANQUILLA
# 546141                 TI           F         ATLANTICO      BARRANQUILLA
# 546148                 TI           F         ATLANTICO      BARRANQUILLA
#
#         PUNT_MATEMATICAS  PUNT_C_NATURALES  PUNT_INGLES  PUNT_LECTURA_CRITICA  \
# ...

# %%
plt.figure(figsize=(8,6));
sns.scatterplot(data=df_baq,x='PUNT_MATEMATICAS',y='PUNT_C_NATURALES',hue='ESTU_GENERO');

# %%
sns.jointplot(data=df_baq, x='PUNT_MATEMATICAS',y='PUNT_INGLES',color='g',kind='kde');

# %%
colu = ['PUNT_MATEMATICAS','PUNT_INGLES','PUNT_C_NATURALES'];
sns.pairplot(data=df_baq, x_vars=colu, y_vars=colu, hue='ESTU_GENERO',height=4);

# %%
df_baq.columns
# Out:
# Index(['ESTU_TIPODOCUMENTO', 'ESTU_GENERO', 'ESTU_DEPTO_RESIDE',
#        'ESTU_MCPIO_RESIDE', 'PUNT_MATEMATICAS', 'PUNT_C_NATURALES',
#        'PUNT_INGLES', 'PUNT_LECTURA_CRITICA', 'PUNT_GLOBAL'],
#       dtype='object')

# %%
sns.boxplot(data=df_baq,x='ESTU_GENERO',y='PUNT_MATEMATICAS', showfliers=False);

# %% [markdown]
# **AGRUPACIONES**
#
# Con los siguientes comandos podemos crear grupos dentro del conjunto de datos original. Para cada grupo podemos calcular datos nuevos interesantes que me describa un poco más sobre cada uno de ellos.

# %%
df1[['ESTU_GENERO','PUNT_MATEMATICAS']]
# Out:
#        ESTU_GENERO  PUNT_MATEMATICAS
# 0                M                48
# 1                M                65
# 2                M                57
# 3                M                54
# 4                M                57
# ...            ...               ...
# 546207           M                78
# 546208           M                73
# 546209           M                83
# 546210           M                61
# 546211           M                73
#
# [546212 rows x 2 columns]

# %%
df1[['ESTU_GENERO','PUNT_MATEMATICAS']].groupby(by=['ESTU_GENERO']).count()
# Out:
#              PUNT_MATEMATICAS
# ESTU_GENERO
# -                         121
# F                      295994
# M                      250097

# %%
df_r = df1[['ESTU_DEPTO_RESIDE', 'PUNT_GLOBAL']].groupby(by=['ESTU_DEPTO_RESIDE']).mean()
df_r
# Out:
#                    PUNT_GLOBAL
# ESTU_DEPTO_RESIDE
# AMAZONAS            213.061818
# ANTIOQUIA           241.928208
# ARAUCA              241.085740
# ATLANTICO           241.557693
# BOGOTÁ              266.450622
# BOLIVAR             227.533886
# BOYACA              261.560461
# CALDAS              246.178376
# CAQUETA             233.480250
# CASANARE            246.739029
# CAUCA               228.094707
# CESAR               238.436502
# CHOCO               200.808793
# CORDOBA             235.604532
# CUNDINAMARCA        253.136341
# EXTRANJERO          235.164179
# GUAINIA             222.988806
# GUAVIARE            224.022616
# HUILA               250.018881
# LA GUAJIRA          218.125679
# MAGDALENA           221.329885
# META                247.901300
# NARIÑO              244.311306
# NORTE SANTANDER     255.308853
# PUTUMAYO            236.573307
# QUINDIO             251.880031
# RISARALDA           250.391402
# SAN ANDRES          230.035088
# ...
